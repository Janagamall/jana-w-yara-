# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/janag/OneDrive/Documents/datascience/project/studentp2.csv')
features = df.iloc[:, :27]
print(features)
target = df.iloc[:, -1]
print(target)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... paid activities  nursery  higher  internet romantic famrel freetime  \
# 0    ...   no         no      yes     yes        no       no      4        3
# 1    ...   no         no       no     yes       yes       no      5        3
# 2    ...   no         no      yes     yes       yes       no      4        3
# 3    ...   no        yes      yes     yes       yes      yes      3        2
# 4    ...   no         no      yes     yes        no       no      4        3
# ..   ...  ...        ...      ...     ...       ...      ...    ...      ...
# 644  ...   no        yes       no     yes       yes       no      5        4
# 645  ...   no         no      yes     yes       yes       no      4        3
# 646  ...   no        yes      yes     yes        no       no      1        1
# 647  ...   no         no       no     yes       yes       no      2        4
# 648  ...   no         no       no     yes       yes       no      4        4
#
#     goout Dalc
# 0       4    1
# 1       3    1
# 2       2    2
# 3       2    1
# 4       2    1
# ..    ...  ...
# 644     2    1
# 645     4    1
# 646     1    1
# 647     5    3
# 648     1    3
#
# [649 rows x 27 columns]
# 0      11
# 1      11
# 2      12
# 3      14
# 4      13
#        ..
# 644    10
# 645    16
# 646     9
# 647    10
# 648    11
# Name: G3, Length: 649, dtype: int64

# %%
for feature_name in features.columns:
    plt.scatter(features[feature_name], target, alpha=0.5)
    plt.xlabel(feature_name)
    plt.ylabel('Target Variable')
    plt.title(f'Scatter plot of {feature_name} vs Target')
    plt.show()

# %%
for feature_name in features.columns:
    plt.figure(figsize=(8, 6))
    feature_counts = features[feature_name].value_counts()
    plt.bar(feature_counts.index, target.groupby(features[feature_name]).mean())
    plt.xlabel(feature_name)
    plt.ylabel('Mean Target Variable')
    plt.title(f'Bar chart of Mean Target Variable vs {feature_name}')
    plt.show()

# %%
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='ignore')

df_numeric = df.select_dtypes(include='number')

target = df_numeric.iloc[:, -1]

features = df_numeric.iloc[:, :-1]

for feature_name in features.columns:
    plt.figure(figsize=(8, 6))
    sns.heatmap(pd.concat([features[feature_name], target], axis=1).corr(), annot=True, cmap='coolwarm', fmt=".2f")
    plt.title(f'Heatmap of Correlation between {feature_name} and Target Variable')
    plt.xlabel('Target Variable')
    plt.ylabel(feature_name)
    plt.show()
# Out:
# C:\Users\janag\AppData\Local\Temp\ipykernel_23512\1378517589.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')
